# %% [markdown]
# # 1️⃣ Training an Adapter for a Transformer model
#
# In this notebook, we train an adapter for a **RoBERTa** ([Liu et al., 2019](https://arxiv.org/pdf/1907.11692.pdf)) model for sequence classification on a **sentiment analysis** task using [adapter-transformers](https://github.com/Adapter-Hub/adapter-transformers), the _AdapterHub_ adaptation of HuggingFace's _transformers_ library.
#
# If you're unfamiliar with the theoretical parts of adapters or the AdapterHub framework, check out our [introductory blog post](https://adapterhub.ml/blog/2020/11/adapting-transformers-with-adapterhub/) first.
#
# We train a **Task Adapter** for a pre-trained model here. Most of the code is identical to a full finetuning setup using HuggingFace's transformers. For comparison, have a look at the [same guide using full finetuning](https://colab.research.google.com/drive/1brXJg5Mokm8h3shxqPRnoIsRwHQoncus?usp=sharing).
#
# For training, we use the [movie review dataset by Pang and Lee (2005)](http://www.cs.cornell.edu/people/pabo/movie-review-data/). It contains movie reviews  from Rotten Tomatoes which are either classified as positive or negative. We download the dataset via HuggingFace's [datasets](https://github.com/huggingface/datasets) library.

# %% [markdown]
# ## Installation
#
# First, let's install the required libraries:

# %%
# !pip install adapter-transformers
# !pip install datasets
# Out:
# Requirement already satisfied: adapter-transformers in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (3.1.0)
# Requirement already satisfied: requests in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from adapter-transformers) (2.28.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from adapter-transformers) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from adapter-transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from adapter-transformers) (0.11.1)
# Requirement already satisfied: tqdm>=4.27 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from adapter-transformers) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from adapter-transformers) (1.23.5)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from adapter-transformers) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from adapter-transformers) (22.0)
# Requirement already satisfied: filelock in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from adapter-transformers) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->adapter-transformers) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from requests->adapter-transformers) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from requests->adapter-transformers) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from requests->adapter-transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from requests->adapter-transformers) (3.4)
# Requirement already satisfied: datasets in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (2.8.0)
# Requirement already satisfied: requests>=2.19.0 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (2.28.1)
# Requirement already satisfied: responses<0.19 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: pandas in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (1.5.2)
# Requirement already satisfied: dill<0.3.7 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: xxhash in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (3.1.0)
# Requirement already satisfied: numpy>=1.17 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (1.23.5)
# Requirement already satisfied: multiprocess in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (2022.11.0)
# Requirement already satisfied: packaging in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (22.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (6.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (4.64.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (10.0.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (0.11.1)
# Requirement already satisfied: aiohttp in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from datasets) (3.8.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: filelock in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from pandas->datasets) (2022.6)
# Requirement already satisfied: six>=1.5 in /home/akiyo/miniconda3/envs/swint/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %% [markdown]
# ## Dataset Preprocessing
#
# Before we start to train our adapter, we first prepare the training data. Our training dataset can be loaded via HuggingFace `datasets` using one line of code:

# %%
from datasets import load_dataset

dataset = load_dataset("rotten_tomatoes")
dataset.num_rows
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from datasets import load_dataset
# ----> 3 dataset = load_dataset("rotten_tomatoes")
#       4 dataset.num_rows
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/datasets/load.py:1734, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, **config_kwargs)
#    1731 ignore_verifications = ignore_verifications or save_infos
#    1733 # Create a dataset builder
# -> 1734 builder_instance = load_dataset_builder(
#    1735     path=path,
#    1736     name=name,
#    1737     data_dir=data_dir,
#    1738     data_files=data_files,
#    1739     cache_dir=cache_dir,
#    1740     features=features,
#    1741     download_config=download_config,
#    1742     download_mode=download_mode,
#    1743     revision=revision,
#    1744     use_auth_token=use_auth_token,
#    1745     **config_kwargs,
#    1746 )
#    1748 # Return iterable dataset in case of streaming
#    1749 if streaming:
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/datasets/load.py:1492, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, use_auth_token, **config_kwargs)
#    1490     download_config = download_config.copy() if download_config else DownloadConfig()
#    1491     download_config.use_auth_token = use_auth_token
# -> 1492 dataset_module = dataset_module_factory(
#    1493     path,
#    1494     revision=revision,
#    1495     download_config=download_config,
#    1496     download_mode=download_mode,
#    1497     data_dir=data_dir,
#    1498     data_files=data_files,
#    1499 )
#    1501 # Get dataset builder class from the processing script
#    1502 builder_cls = import_main_class(dataset_module.module_path)
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/datasets/load.py:1187, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, **download_kwargs)
#    1185         raise e
#    1186 if filename in [sibling.rfilename for sibling in dataset_info.siblings]:
# -> 1187     return HubDatasetModuleFactoryWithScript(
#    1188         path,
#    1189         revision=revision,
#    1190         download_config=download_config,
#    1191         download_mode=download_mode,
#    1192         dynamic_modules_path=dynamic_modules_path,
#    1193     ).get_module()
#    1194 else:
#    1195     return HubDatasetModuleFactoryWithoutScript(
#    1196         path,
#    1197         revision=revision,
#    (...)
#    1201         download_mode=download_mode,
#    1202     ).get_module()
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/datasets/load.py:903, in HubDatasetModuleFactoryWithScript.get_module(self)
#     900 def get_module(self) -> DatasetModule:
#     901     # get script and other files
#     902     local_path = self.download_loading_script()
# --> 903     dataset_infos_path = self.download_dataset_infos_file()
#     904     dataset_readme_path = self.download_dataset_readme_file()
#     905     imports = get_imports(local_path)
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/datasets/load.py:879, in HubDatasetModuleFactoryWithScript.download_dataset_infos_file(self)
#     877     download_config.download_desc = "Downloading metadata"
#     878 try:
# --> 879     return cached_path(
#     880         dataset_infos,
#     881         download_config=download_config,
#     882     )
#     883 except (FileNotFoundError, ConnectionError):
#     884     return None
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/datasets/utils/file_utils.py:183, in cached_path(url_or_filename, download_config, **download_kwargs)
#     179     url_or_filename = str(url_or_filename)
#     181 if is_remote_url(url_or_filename):
#     182     # URL, so get it from the cache (downloading if necessary)
# --> 183     output_path = get_from_cache(
#     184         url_or_filename,
#     185         cache_dir=cache_dir,
#     186         force_download=download_config.force_download,
#     187         proxies=download_config.proxies,
#     188         resume_download=download_config.resume_download,
#     189         user_agent=download_config.user_agent,
#     190         local_files_only=download_config.local_files_only,
#     191         use_etag=download_config.use_etag,
#     192         max_retries=download_config.max_retries,
#     193         use_auth_token=download_config.use_auth_token,
#     194         ignore_url_params=download_config.ignore_url_params,
#     195         download_desc=download_config.download_desc,
#     196     )
#     197 elif os.path.exists(url_or_filename):
#     198     # File, and it exists.
#     199     output_path = url_or_filename
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/datasets/utils/file_utils.py:476, in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, local_files_only, use_etag, max_retries, use_auth_token, ignore_url_params, download_desc)
#     474     connected = ftp_head(url)
#     475 try:
# --> 476     response = http_head(
#     477         url,
#     478         allow_redirects=True,
#     479         proxies=proxies,
#     480         timeout=etag_timeout,
#     481         max_retries=max_retries,
#     482         headers=headers,
#     483     )
#     484     if response.status_code == 200:  # ok
#     485         etag = response.headers.get("ETag") if use_etag else None
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/datasets/utils/file_utils.py:390, in http_head(url, proxies, headers, cookies, allow_redirects, timeout, max_retries)
#     388 headers = copy.deepcopy(headers) or {}
#     389 headers["user-agent"] = get_datasets_user_agent(user_agent=headers.get("user-agent"))
# --> 390 response = _request_with_retry(
#     391     method="HEAD",
#     392     url=url,
#     393     proxies=proxies,
#     394     headers=headers,
#     395     cookies=cookies,
#     396     allow_redirects=allow_redirects,
#     397     timeout=timeout,
#     398     max_retries=max_retries,
#     399 )
#     400 return response
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/datasets/utils/file_utils.py:319, in _request_with_retry(method, url, max_retries, base_wait_time, max_wait_time, timeout, **params)
#     317 tries += 1
#     318 try:
# --> 319     response = requests.request(method=method.upper(), url=url, timeout=timeout, **params)
#     320     success = True
#     321 except (requests.exceptions.ConnectTimeout, requests.exceptions.ConnectionError) as err:
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/miniconda3/envs/swint/lib/python3.8/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~/miniconda3/envs/swint/lib/python3.8/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~/miniconda3/envs/swint/lib/python3.8/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1037         if timeout == 0.0:
#    1038             # non-blocking
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#    1042     self.close()
#
# File ~/miniconda3/envs/swint/lib/python3.8/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1307     if timeout == 0.0 and block:
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#    1311     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %% [markdown]
# Every dataset sample has an input text and a binary label:

# %%
dataset['train'][0]
# Out:
# {'text': 'the rock is destined to be the 21st century\'s new " conan " and that he\'s going to make a splash even greater than arnold schwarzenegger , jean-claud van damme or steven segal .',
#  'label': 1}

# %% [markdown]
# Now, we need to encode all dataset samples to valid inputs for our Transformer model. Since we want to train on `roberta-base`, we load the corresponding `RobertaTokenizer`. Using `dataset.map()`, we can pass the full dataset through the tokenizer in batches:

# %%
from transformers import RobertaTokenizer

tokenizer = RobertaTokenizer.from_pretrained("roberta-base")

def encode_batch(batch):
  """Encodes a batch of input data using the model tokenizer."""
  return tokenizer(batch["text"], max_length=80, truncation=True, padding="max_length")

# Encode the input data
dataset = dataset.map(encode_batch, batched=True)
# The transformers model expects the target class column to be named "labels"
dataset.rename_column_("label", "labels")
# Transform to pytorch tensors and only output the required columns
dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
# Out:
# Downloading vocab.json: 100%|██████████| 878k/878k [00:00<00:00, 1.04MB/s]
# Downloading merges.txt: 100%|██████████| 446k/446k [00:00<00:00, 527kB/s]
# Downloading config.json: 100%|██████████| 481/481 [00:00<00:00, 205kB/s]
# 100%|██████████| 9/9 [00:05<00:00,  1.70ba/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.47ba/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.69ba/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 12
#      10 dataset = dataset.map(encode_batch, batched=True)
#      11 # The transformers model expects the target class column to be named "labels"
# ---> 12 dataset.rename_column_("label", "labels")
#      13 # Transform to pytorch tensors and only output the required columns
#      14 dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
#
# AttributeError: 'DatasetDict' object has no attribute 'rename_column_'

# %% [markdown]
# Now we're ready to train our model...

# %% [markdown]
# ## Training
#
# We use a pre-trained RoBERTa model from HuggingFace. We use `RobertaModelWithHeads`, a class unique to `adapter-transformers`, which allows us to add and configure prediction heads in a flexibler way.

# %%
from transformers import RobertaConfig, RobertaModelWithHeads

config = RobertaConfig.from_pretrained(
    "roberta-base",
    num_labels=2,
)
model = RobertaModelWithHeads.from_pretrained(
    "roberta-base",
    config=config,
)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModelWithHeads: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModelWithHeads from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModelWithHeads from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModelWithHeads were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# **Here comes the important part!**
#
# We add a new adapter to our model by calling `add_adapter()`. We pass a name (`"rotten_tomatoes"`) and [the type of adapter](https://docs.adapterhub.ml/adapters.html#adapter-types) (task adapter). Next, we add a binary classification head. It's convenient to give the prediction head the same name as the adapter. This allows us to activate both together in the next step. The `train_adapter()` method does two things:
#
# 1. It freezes all weights of the pre-trained model so only the adapter weights are updated during training.
# 2. It activates the adapter and the prediction head such that both are used in every forward pass.

# %%
# Add a new adapter
model.add_adapter("rotten_tomatoes")
# Add a matching classification head
model.add_classification_head(
    "rotten_tomatoes",
    num_labels=2,
    id2label={ 0: "👎", 1: "👍"}
  )
# Activate the adapter
model.train_adapter("rotten_tomatoes")

# %% [markdown]
# For training, we make use of the `Trainer` class built-in into `transformers`. We configure the training process using a `TrainingArguments` object and define a method that will calculate the evaluation accuracy in the end. We pass both, together with the training and validation split of our dataset, to the trainer instance.
#
# **Note the differences in hyperparameters compared to full finetuning.** Adapter training usually required a few more training epochs than full finetuning.

# %%
import numpy as np
from transformers import TrainingArguments, AdapterTrainer, EvalPrediction

training_args = TrainingArguments(
    learning_rate=1e-4,
    num_train_epochs=6,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    logging_steps=200,
    output_dir="./training_output",
    overwrite_output_dir=True,
    # The next line is important to ensure the dataset labels are properly passed to the model
    remove_unused_columns=False,
)

def compute_accuracy(p: EvalPrediction):
  preds = np.argmax(p.predictions, axis=1)
  return {"acc": (preds == p.label_ids).mean()}

trainer = AdapterTrainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["validation"],
    compute_metrics=compute_accuracy,
)

# %% [markdown]
# Start the training 🚀

# %%
trainer.train()
# Out:
# c:\users\hster\pycharmprojects\hiwi\adapter-transformers\datasets\src\datasets\arrow_dataset.py:850: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='1602' max='1602' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1602/1602 18:04, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>200</td>
#       <td>0.486505</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.323210</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.286104</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.269505</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.251211</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.241115</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.232532</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.227369</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1602, training_loss=0.2895852146523722)

# %% [markdown]
# Looks good! Let's evaluate our adapter on the validation split of the dataset to see how well it learned:

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='34' max='34' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [34/34 00:10]
#     </div>
# {'eval_loss': 0.27678099274635315,
#  'eval_acc': 0.8911819887429644,
#  'epoch': 6.0}

# %% [markdown]
# We can put our trained model into a `transformers` pipeline to be able to make new predictions conveniently:

# %%
from transformers import TextClassificationPipeline

classifier = TextClassificationPipeline(model=model, tokenizer=tokenizer, device=training_args.device.index)

classifier("This is awesome!")
# Out:
# [{'label': '👍', 'score': 0.9894458055496216}]

# %% [markdown]
# At last, we can also extract the adapter from our model and separately save it for later reuse. Note the size difference compared to a full model!

# %%
model.save_adapter("./final_adapter", "rotten_tomatoes")

# !ls -lh final_adapter
# Out:
# Der Befehl "ls" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.

# %% [markdown]
# **Share your work!**
#
# The next step after training is to share our adapter with the world via _AdapterHub_. [Read our guide](https://docs.adapterhub.ml/contributing.html) on how to prepare the adapter module we just saved and contribute it to the Hub!
#
# ➡️ Also continue with [the next Colab notebook](https://colab.research.google.com/github/Adapter-Hub/adapter-transformers/blob/master/notebooks/02_Adapter_Inference.ipynb) to learn how to use adapters from the Hub.
